# %% [markdown]
# # Experiment 4

# %%
def run_lunar(r, b):
    # !python ./run_hw2.py --env_name HalfCheetah-v2 --ep_len 150 \
    --discount 0.95 -n 100 -l 2 -s 32 -b {b} -lr {r} -rtg --nn_baseline \
    --exp_name q4_search_b{b}_lr{r}_rtg_nnbaseline

for b in  [10000, 30000, 50000]:
    for lr in [0.005, 0.01, 0.02]:
        run_lunar(lr, b)
# Out:
# ########################
# logging outputs to  /home/tomas/Documents/cs285/homework_fall2020/hw2/cs285/scripts/../../data/q4_search_b10000_lr0.005_rtg_nnbaseline_HalfCheetah-v2_25-09-2020_19-10-10
# ########################
# Using GPU id 0
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -92.88306427001953
# Eval_StdReturn : 40.07961654663086
# Eval_MaxReturn : -36.619117736816406
# Eval_MinReturn : -126.95976257324219
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -87.20951843261719
# Train_StdReturn : 43.93048858642578
# Train_MaxReturn : -1.1699542999267578
# Train_MinReturn : -188.06881713867188
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 10117
# TimeSinceStart : 7.2943034172058105
# Training Loss : -669.626220703125
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -43.47612380981445
# Eval_StdReturn : 6.646758079528809
# Eval_MaxReturn : -35.31611633300781
# Eval_MinReturn : -51.59714126586914
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -83.52891540527344
# Train_StdReturn : 37.507843017578125
# Train_MaxReturn : 3.521291732788086
# Train_MinReturn : -219.7670135498047
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 20234
# TimeSinceStart : 14.660795450210571
# Training Loss : -990.1695556640625
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -83.833984375
# Eval_StdReturn : 11.303980827331543
# Eval_MaxReturn : -71.69548797607422
# Eval_MinReturn : -98.91226196289062
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -87.10359191894531
# Train_StdReturn : 32.19590759277344
# Train_MaxReturn : -15.67584228515625
# Train_MinReturn : -172.20733642578125
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 30351
# TimeSinceStart : 21.802303552627563
# Training Loss : -580.6126708984375
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -80.91802978515625
# Eval_StdReturn : 20.024423599243164
# Eval_MaxReturn : -60.071590423583984
# Eval_MinReturn : -107.94052124023438
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -76.68795776367188
# Train_StdReturn : 38.308841705322266
# Train_MaxReturn : 2.1065101623535156
# Train_MinReturn : -195.72921752929688
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 40468
# TimeSinceStart : 29.31533932685852
# Training Loss : -844.10888671875
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -61.79563903808594
# Eval_StdReturn : 33.362823486328125
# Eval_MaxReturn : -33.68044662475586
# Eval_MinReturn : -108.66739654541016
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -84.2671127319336
# Train_StdReturn : 36.12324142456055
# Train_MaxReturn : -12.937973022460938
# Train_MinReturn : -211.46188354492188
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 50585
# TimeSinceStart : 36.607325077056885
# Training Loss : -688.552734375
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -67.17302703857422
# Eval_StdReturn : 40.23716354370117
# Eval_MaxReturn : -28.123310089111328
# Eval_MinReturn : -122.54316711425781
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -79.2499771118164
# Train_StdReturn : 34.520416259765625
# Train_MaxReturn : -6.177289009094238
# Train_MinReturn : -172.54190063476562
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 60702
# TimeSinceStart : 44.287092208862305
# Training Loss : -754.7508544921875
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -98.69486236572266
# Eval_StdReturn : 36.001708984375
# Eval_MaxReturn : -62.915863037109375
# Eval_MinReturn : -147.95443725585938
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -79.5532455444336
# Train_StdReturn : 28.8402099609375
# Train_MaxReturn : 2.2437243461608887
# Train_MinReturn : -142.99415588378906
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 70819
# TimeSinceStart : 52.34875416755676
# Training Loss : -1027.601318359375
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -98.93121337890625
# Eval_StdReturn : 11.777498245239258
# Eval_MaxReturn : -90.27531433105469
# Eval_MinReturn : -115.58274841308594
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -76.51411437988281
# Train_StdReturn : 31.26017189025879
# Train_MaxReturn : 8.888675689697266
# Train_MinReturn : -162.70913696289062
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 80936
# TimeSinceStart : 61.3853554725647
# Training Loss : -661.1264038085938
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -108.77457427978516
# Eval_StdReturn : 43.58412170410156
# Eval_MaxReturn : -47.861080169677734
# Eval_MinReturn : -147.387451171875
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -74.04988861083984
# Train_StdReturn : 35.04496765136719
# Train_MaxReturn : 7.27783203125
# Train_MinReturn : -172.69650268554688
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 91053
# TimeSinceStart : 69.85533595085144
# Training Loss : -895.8259887695312
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -83.85921478271484
# Eval_StdReturn : 25.37115478515625
# Eval_MaxReturn : -64.56494903564453
# Eval_MinReturn : -119.70447540283203
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -70.3144302368164
# Train_StdReturn : 37.29749298095703
# Train_MaxReturn : 17.967960357666016
# Train_MinReturn : -173.71383666992188
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 101170
# TimeSinceStart : 77.24361228942871
# Training Loss : -726.4490966796875
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -69.93558502197266
# Eval_StdReturn : 24.795034408569336
# Eval_MaxReturn : -35.7662467956543
# Eval_MinReturn : -93.84176635742188
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -71.02976989746094
# Train_StdReturn : 32.010704040527344
# Train_MaxReturn : -12.259488105773926
# Train_MinReturn : -161.77279663085938
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 111287
# TimeSinceStart : 84.56333065032959
# Training Loss : -736.43701171875
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -66.87826538085938
# Eval_StdReturn : 16.572490692138672
# Eval_MaxReturn : -44.11661911010742
# Eval_MinReturn : -83.09662628173828
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -66.57457733154297
# Train_StdReturn : 31.219018936157227
# Train_MaxReturn : 0.45108985900878906
# Train_MinReturn : -154.360107421875
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 121404
# TimeSinceStart : 91.90040636062622
# Training Loss : -893.5948486328125
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -97.38040161132812
# Eval_StdReturn : 26.911300659179688
# Eval_MaxReturn : -67.17245483398438
# Eval_MinReturn : -132.53274536132812
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -71.35555267333984
# Train_StdReturn : 30.962120056152344
# Train_MaxReturn : 17.52398681640625
# Train_MinReturn : -141.56961059570312
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 131521
# TimeSinceStart : 99.27990579605103
# Training Loss : -749.979736328125
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -66.2936019897461
# Eval_StdReturn : 11.617518424987793
# Eval_MaxReturn : -53.116546630859375
# Eval_MinReturn : -81.38059997558594
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -66.92637634277344
# Train_StdReturn : 31.05080223083496
# Train_MaxReturn : -3.9854984283447266
# Train_MinReturn : -136.46913146972656
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 141638
# TimeSinceStart : 106.66652965545654
# Training Loss : -699.55224609375
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -84.7417984008789
# Eval_StdReturn : 27.202957153320312
# Eval_MaxReturn : -46.53228759765625
# Eval_MinReturn : -107.72293853759766
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -70.563720703125
# Train_StdReturn : 34.57882308959961
# Train_MaxReturn : -2.085853099822998
# Train_MinReturn : -153.49057006835938
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 151755
# TimeSinceStart : 113.8447892665863
# Training Loss : -947.40478515625
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -89.70084381103516
# Eval_StdReturn : 29.488544464111328
# Eval_MaxReturn : -51.11845397949219
# Eval_MinReturn : -122.70008850097656
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -60.0904541015625
# Train_StdReturn : 32.02617645263672
# Train_MaxReturn : 25.155227661132812
# Train_MinReturn : -164.23187255859375
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 161872
# TimeSinceStart : 120.91920161247253
# Training Loss : -667.3770141601562
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -26.195566177368164
# Eval_StdReturn : 11.323647499084473
# Eval_MaxReturn : -12.241972923278809
# Eval_MinReturn : -39.9775390625
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -65.5868911743164
# Train_StdReturn : 34.27314758300781
# Train_MaxReturn : -0.527461051940918
# Train_MinReturn : -151.8873748779297
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 171989
# TimeSinceStart : 128.12723875045776
# Training Loss : -490.81640625
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -77.46427154541016
# Eval_StdReturn : 34.69827651977539
# Eval_MaxReturn : -36.528133392333984
# Eval_MinReturn : -121.3658676147461
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -57.805992126464844
# Train_StdReturn : 31.666778564453125
# Train_MaxReturn : 11.55986499786377
# Train_MinReturn : -152.26052856445312
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 182106
# TimeSinceStart : 135.2260866165161
# Training Loss : -702.54150390625
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -66.36795806884766
# Eval_StdReturn : 25.6614933013916
# Eval_MaxReturn : -32.63591766357422
# Eval_MinReturn : -94.82624053955078
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -59.31302261352539
# Train_StdReturn : 27.235092163085938
# Train_MaxReturn : 12.3617525100708
# Train_MinReturn : -106.69185638427734
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 192223
# TimeSinceStart : 142.38557410240173
# Training Loss : -731.59375
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -80.88936614990234
# Eval_StdReturn : 45.1072883605957
# Eval_MaxReturn : -17.111278533935547
# Eval_MinReturn : -113.90450286865234
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -62.21028137207031
# Train_StdReturn : 35.45433807373047
# Train_MaxReturn : 22.384353637695312
# Train_MinReturn : -204.61566162109375
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 202340
# TimeSinceStart : 149.8431465625763
# Training Loss : -704.0997314453125
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -50.01839828491211
# Eval_StdReturn : 15.740894317626953
# Eval_MaxReturn : -34.01594924926758
# Eval_MinReturn : -71.42129516601562
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -52.69599151611328
# Train_StdReturn : 22.85494041442871
# Train_MaxReturn : -3.5942916870117188
# Train_MinReturn : -118.19918823242188
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 212457
# TimeSinceStart : 157.2975401878357
# Training Loss : -782.461669921875
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -38.11721420288086
# Eval_StdReturn : 39.30934524536133
# Eval_MaxReturn : 16.00400733947754
# Eval_MinReturn : -76.17811584472656
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -61.117679595947266
# Train_StdReturn : 29.856977462768555
# Train_MaxReturn : -11.775884628295898
# Train_MinReturn : -136.49325561523438
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 222574
# TimeSinceStart : 164.7219157218933
# Training Loss : -1028.84912109375
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -58.74928665161133
# Eval_StdReturn : 38.498046875
# Eval_MaxReturn : -16.67380714416504
# Eval_MinReturn : -109.71009826660156
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -55.351131439208984
# Train_StdReturn : 31.5128116607666
# Train_MaxReturn : 14.808425903320312
# Train_MinReturn : -133.8023681640625
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 232691
# TimeSinceStart : 172.15133023262024
# Training Loss : -1209.3201904296875
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -42.12633514404297
# Eval_StdReturn : 17.551355361938477
# Eval_MaxReturn : -17.345849990844727
# Eval_MinReturn : -55.74979019165039
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -62.863304138183594
# Train_StdReturn : 29.91488265991211
# Train_MaxReturn : -3.227255344390869
# Train_MinReturn : -158.6641845703125
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 242808
# TimeSinceStart : 179.56298446655273
# Training Loss : -742.4960327148438
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -66.3272476196289
# Eval_StdReturn : 18.5889835357666
# Eval_MaxReturn : -44.19171905517578
# Eval_MinReturn : -89.67667388916016
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -52.14914321899414
# Train_StdReturn : 27.48700714111328
# Train_MaxReturn : 13.254395484924316
# Train_MinReturn : -109.69644927978516
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 252925
# TimeSinceStart : 186.9826056957245
# Training Loss : -696.289794921875
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -29.551485061645508
# Eval_StdReturn : 13.837359428405762
# Eval_MaxReturn : -15.072080612182617
# Eval_MinReturn : -48.19157791137695
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -52.848365783691406
# Train_StdReturn : 24.515666961669922
# Train_MaxReturn : 14.802806854248047
# Train_MinReturn : -97.07351684570312
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 263042
# TimeSinceStart : 194.50174379348755
# Training Loss : -700.93505859375
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -71.89202117919922
# Eval_StdReturn : 9.222186088562012
# Eval_MaxReturn : -62.637413024902344
# Eval_MinReturn : -84.47779846191406
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -57.96990203857422
# Train_StdReturn : 32.2792854309082
# Train_MaxReturn : 9.145532608032227
# Train_MinReturn : -148.42108154296875
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 273159
# TimeSinceStart : 201.87767219543457
# Training Loss : -863.7169189453125
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -39.57204055786133
# Eval_StdReturn : 28.966745376586914
# Eval_MaxReturn : 0.6216249465942383
# Eval_MinReturn : -66.52163696289062
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -56.402774810791016
# Train_StdReturn : 35.49656295776367
# Train_MaxReturn : 9.248197555541992
# Train_MinReturn : -181.48629760742188
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 283276
# TimeSinceStart : 209.2432951927185
# Training Loss : -782.96923828125
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -60.405826568603516
# Eval_StdReturn : 10.132322311401367
# Eval_MaxReturn : -49.36552429199219
# Eval_MinReturn : -73.83671569824219
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -51.767608642578125
# Train_StdReturn : 31.706750869750977
# Train_MaxReturn : 5.387218952178955
# Train_MinReturn : -121.24807739257812
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 293393
# TimeSinceStart : 216.36398649215698
# Training Loss : -835.497314453125
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -57.16331481933594
# Eval_StdReturn : 4.976624488830566
# Eval_MaxReturn : -50.16926574707031
# Eval_MinReturn : -61.340511322021484
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -53.092281341552734
# Train_StdReturn : 30.366539001464844
# Train_MaxReturn : 25.98029136657715
# Train_MinReturn : -146.61654663085938
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 303510
# TimeSinceStart : 223.4553039073944
# Training Loss : -1006.98046875
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -81.19803619384766
# Eval_StdReturn : 11.81966495513916
# Eval_MaxReturn : -69.75599670410156
# Eval_MinReturn : -97.47209167480469
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -55.25159454345703
# Train_StdReturn : 31.6531982421875
# Train_MaxReturn : 41.47697830200195
# Train_MinReturn : -178.93319702148438
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 313627
# TimeSinceStart : 230.6107726097107
# Training Loss : -637.64013671875
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -75.46279907226562
# Eval_StdReturn : 33.2703742980957
# Eval_MaxReturn : -32.030174255371094
# Eval_MinReturn : -112.85016632080078
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -54.36045837402344
# Train_StdReturn : 23.548940658569336
# Train_MaxReturn : -11.975160598754883
# Train_MinReturn : -117.84548950195312
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 323744
# TimeSinceStart : 237.77789521217346
# Training Loss : -787.198974609375
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -52.982479095458984
# Eval_StdReturn : 15.21178150177002
# Eval_MaxReturn : -39.157100677490234
# Eval_MinReturn : -74.16897583007812
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -51.629215240478516
# Train_StdReturn : 31.669677734375
# Train_MaxReturn : 42.37194061279297
# Train_MinReturn : -119.37857055664062
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 333861
# TimeSinceStart : 245.16802787780762
# Training Loss : -615.053955078125
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -82.09738159179688
# Eval_StdReturn : 15.904165267944336
# Eval_MaxReturn : -65.6559066772461
# Eval_MinReturn : -103.60992431640625
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -51.5446662902832
# Train_StdReturn : 29.477293014526367
# Train_MaxReturn : 50.60702133178711
# Train_MinReturn : -109.65431213378906
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 343978
# TimeSinceStart : 252.6320354938507
# Training Loss : -749.354248046875
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -56.6665153503418
# Eval_StdReturn : 11.827880859375
# Eval_MaxReturn : -39.94429016113281
# Eval_MinReturn : -65.37911987304688
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -51.568145751953125
# Train_StdReturn : 33.69846725463867
# Train_MaxReturn : 33.608028411865234
# Train_MinReturn : -156.60597229003906
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 354095
# TimeSinceStart : 260.1181972026825
# Training Loss : -664.228271484375
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -35.166839599609375
# Eval_StdReturn : 41.44892120361328
# Eval_MaxReturn : 20.395442962646484
# Eval_MinReturn : -79.12339782714844
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -47.019500732421875
# Train_StdReturn : 36.16767883300781
# Train_MaxReturn : 22.150808334350586
# Train_MinReturn : -142.6694793701172
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 364212
# TimeSinceStart : 267.53200483322144
# Training Loss : -737.015869140625
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -71.61125946044922
# Eval_StdReturn : 56.322994232177734
# Eval_MaxReturn : -28.205421447753906
# Eval_MinReturn : -151.15335083007812
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -48.82172393798828
# Train_StdReturn : 29.808679580688477
# Train_MaxReturn : -3.977282762527466
# Train_MinReturn : -171.41058349609375
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 374329
# TimeSinceStart : 274.9421169757843
# Training Loss : -613.7685546875
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -32.20864486694336
# Eval_StdReturn : 21.787307739257812
# Eval_MaxReturn : -11.109664916992188
# Eval_MinReturn : -62.204341888427734
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -44.41183853149414
# Train_StdReturn : 25.716018676757812
# Train_MaxReturn : 17.150936126708984
# Train_MinReturn : -120.314697265625
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 384446
# TimeSinceStart : 282.35582852363586
# Training Loss : -496.73236083984375
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -42.21480178833008
# Eval_StdReturn : 23.88506317138672
# Eval_MaxReturn : -8.764833450317383
# Eval_MinReturn : -63.01031494140625
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -45.15178298950195
# Train_StdReturn : 23.573020935058594
# Train_MaxReturn : 7.193521499633789
# Train_MinReturn : -97.82920837402344
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 394563
# TimeSinceStart : 289.84500670433044
# Training Loss : -1005.77197265625
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -64.44855499267578
# Eval_StdReturn : 36.837791442871094
# Eval_MaxReturn : -26.409019470214844
# Eval_MinReturn : -114.29492950439453
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -48.957313537597656
# Train_StdReturn : 31.401161193847656
# Train_MaxReturn : 14.001680374145508
# Train_MinReturn : -155.1855010986328
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 404680
# TimeSinceStart : 297.2460377216339
# Training Loss : -628.7594604492188
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -18.21221923828125
# Eval_StdReturn : 9.381760597229004
# Eval_MaxReturn : -5.010181903839111
# Eval_MinReturn : -25.955955505371094
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -46.63327407836914
# Train_StdReturn : 25.861421585083008
# Train_MaxReturn : 29.771686553955078
# Train_MinReturn : -131.01885986328125
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 414797
# TimeSinceStart : 304.58727955818176
# Training Loss : -1009.6778564453125
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -35.35151290893555
# Eval_StdReturn : 20.99993896484375
# Eval_MaxReturn : -20.088050842285156
# Eval_MinReturn : -65.0460205078125
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -46.858787536621094
# Train_StdReturn : 26.011014938354492
# Train_MaxReturn : 7.10693359375
# Train_MinReturn : -117.5243911743164
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 424914
# TimeSinceStart : 311.6874306201935
# Training Loss : -716.071044921875
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -30.269330978393555
# Eval_StdReturn : 4.544188022613525
# Eval_MaxReturn : -26.159536361694336
# Eval_MinReturn : -36.60285568237305
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -41.68439865112305
# Train_StdReturn : 22.590150833129883
# Train_MaxReturn : 1.8415985107421875
# Train_MinReturn : -89.74510192871094
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 435031
# TimeSinceStart : 318.88150215148926
# Training Loss : -727.6504516601562
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -31.3021297454834
# Eval_StdReturn : 37.737281799316406
# Eval_MaxReturn : 21.404603958129883
# Eval_MinReturn : -64.91182708740234
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -39.13140869140625
# Train_StdReturn : 23.49447250366211
# Train_MaxReturn : 15.971978187561035
# Train_MinReturn : -116.40128326416016
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 445148
# TimeSinceStart : 326.0097954273224
# Training Loss : -746.1514892578125
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -48.376102447509766
# Eval_StdReturn : 10.01882553100586
# Eval_MaxReturn : -39.75297927856445
# Eval_MinReturn : -62.42402267456055
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -41.064090728759766
# Train_StdReturn : 26.152482986450195
# Train_MaxReturn : 24.35661506652832
# Train_MinReturn : -93.57393646240234
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 455265
# TimeSinceStart : 333.20628237724304
# Training Loss : -803.8667602539062
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -57.45048904418945
# Eval_StdReturn : 23.533096313476562
# Eval_MaxReturn : -26.35675811767578
# Eval_MinReturn : -83.27328491210938
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -44.50196075439453
# Train_StdReturn : 29.125286102294922
# Train_MaxReturn : 21.746904373168945
# Train_MinReturn : -139.1311798095703
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 465382
# TimeSinceStart : 340.5144636631012
# Training Loss : -896.2861328125
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -49.69044494628906
# Eval_StdReturn : 15.160079002380371
# Eval_MaxReturn : -30.171775817871094
# Eval_MinReturn : -67.13145446777344
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -43.21363830566406
# Train_StdReturn : 24.366409301757812
# Train_MaxReturn : 0.7786073684692383
# Train_MinReturn : -102.95203399658203
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 475499
# TimeSinceStart : 347.98068165779114
# Training Loss : -596.80517578125
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -45.25046157836914
# Eval_StdReturn : 21.15884017944336
# Eval_MaxReturn : -23.26800537109375
# Eval_MinReturn : -73.82360076904297
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -43.9715576171875
# Train_StdReturn : 27.14725112915039
# Train_MaxReturn : 15.649974822998047
# Train_MinReturn : -162.5321502685547
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 485616
# TimeSinceStart : 355.4170813560486
# Training Loss : -1222.9755859375
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -59.27171325683594
# Eval_StdReturn : 29.803157806396484
# Eval_MaxReturn : -27.781238555908203
# Eval_MinReturn : -99.27812957763672
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -43.214012145996094
# Train_StdReturn : 26.418668746948242
# Train_MaxReturn : 36.38229751586914
# Train_MinReturn : -121.45160675048828
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 495733
# TimeSinceStart : 363.0194709300995
# Training Loss : -764.0986328125
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -41.5200080871582
# Eval_StdReturn : 7.87185001373291
# Eval_MaxReturn : -30.705333709716797
# Eval_MinReturn : -49.214515686035156
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -40.71349334716797
# Train_StdReturn : 23.509733200073242
# Train_MaxReturn : 21.215171813964844
# Train_MinReturn : -95.14178466796875
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 505850
# TimeSinceStart : 370.52519035339355
# Training Loss : -935.3912353515625
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -26.078325271606445
# Eval_StdReturn : 7.7592363357543945
# Eval_MaxReturn : -15.302002906799316
# Eval_MinReturn : -33.25863265991211
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -34.64604187011719
# Train_StdReturn : 28.461206436157227
# Train_MaxReturn : 37.74832534790039
# Train_MinReturn : -107.37505340576172
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 515967
# TimeSinceStart : 377.9600944519043
# Training Loss : -856.864013671875
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -37.677494049072266
# Eval_StdReturn : 4.891114711761475
# Eval_MaxReturn : -31.997333526611328
# Eval_MinReturn : -43.93610382080078
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -42.40484619140625
# Train_StdReturn : 25.638639450073242
# Train_MaxReturn : 7.094999313354492
# Train_MinReturn : -97.19168090820312
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 526084
# TimeSinceStart : 385.38863492012024
# Training Loss : -891.6640625
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -18.49699592590332
# Eval_StdReturn : 23.768020629882812
# Eval_MaxReturn : 1.4180476665496826
# Eval_MinReturn : -51.90492248535156
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -43.6585693359375
# Train_StdReturn : 24.27924156188965
# Train_MaxReturn : 21.70733642578125
# Train_MinReturn : -115.36956787109375
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 536201
# TimeSinceStart : 392.84837651252747
# Training Loss : -950.4705810546875
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -24.08335304260254
# Eval_StdReturn : 16.507734298706055
# Eval_MaxReturn : -9.968912124633789
# Eval_MinReturn : -47.2447624206543
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -39.90012741088867
# Train_StdReturn : 22.215137481689453
# Train_MaxReturn : 8.650777816772461
# Train_MinReturn : -96.77545166015625
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 546318
# TimeSinceStart : 400.30112981796265
# Training Loss : -952.621826171875
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -34.0372200012207
# Eval_StdReturn : 7.206047534942627
# Eval_MaxReturn : -23.925975799560547
# Eval_MinReturn : -40.19408416748047
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -40.683876037597656
# Train_StdReturn : 23.533164978027344
# Train_MaxReturn : 23.57607650756836
# Train_MinReturn : -92.000244140625
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 556435
# TimeSinceStart : 407.6507980823517
# Training Loss : -755.2027587890625
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -35.84098815917969
# Eval_StdReturn : 6.156276702880859
# Eval_MaxReturn : -30.696781158447266
# Eval_MinReturn : -44.496055603027344
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -36.50694274902344
# Train_StdReturn : 20.046405792236328
# Train_MaxReturn : 12.598703384399414
# Train_MinReturn : -83.1587905883789
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 566552
# TimeSinceStart : 414.91390347480774
# Training Loss : -1005.3611450195312
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -70.01854705810547
# Eval_StdReturn : 33.40553283691406
# Eval_MaxReturn : -41.75469207763672
# Eval_MinReturn : -116.93400573730469
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -37.6626091003418
# Train_StdReturn : 24.804311752319336
# Train_MaxReturn : 25.936607360839844
# Train_MinReturn : -113.660888671875
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 576669
# TimeSinceStart : 422.10621643066406
# Training Loss : -1163.57275390625
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -22.737953186035156
# Eval_StdReturn : 11.848233222961426
# Eval_MaxReturn : -9.300323486328125
# Eval_MinReturn : -38.12530517578125
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -36.24849319458008
# Train_StdReturn : 20.64388656616211
# Train_MaxReturn : 12.586769104003906
# Train_MinReturn : -92.06199645996094
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 586786
# TimeSinceStart : 429.3031704425812
# Training Loss : -929.339599609375
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -28.55230140686035
# Eval_StdReturn : 21.653034210205078
# Eval_MaxReturn : -2.84863018989563
# Eval_MinReturn : -55.81842803955078
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -32.176700592041016
# Train_StdReturn : 21.311473846435547
# Train_MaxReturn : 24.698179244995117
# Train_MinReturn : -88.2252197265625
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 596903
# TimeSinceStart : 436.4544348716736
# Training Loss : -723.7138671875
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -51.0918083190918
# Eval_StdReturn : 11.116223335266113
# Eval_MaxReturn : -41.05973815917969
# Eval_MinReturn : -66.58991241455078
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -37.60747528076172
# Train_StdReturn : 22.498342514038086
# Train_MaxReturn : 17.698814392089844
# Train_MinReturn : -111.74300384521484
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 607020
# TimeSinceStart : 443.97528290748596
# Training Loss : -767.2899780273438
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -34.12033462524414
# Eval_StdReturn : 13.284618377685547
# Eval_MaxReturn : -18.90302848815918
# Eval_MinReturn : -51.27083206176758
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -34.97028350830078
# Train_StdReturn : 22.451025009155273
# Train_MaxReturn : 17.621305465698242
# Train_MinReturn : -116.54962158203125
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 617137
# TimeSinceStart : 451.3372347354889
# Training Loss : -790.484130859375
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -32.31364822387695
# Eval_StdReturn : 10.248198509216309
# Eval_MaxReturn : -20.155067443847656
# Eval_MinReturn : -45.22412109375
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -28.51118278503418
# Train_StdReturn : 22.392288208007812
# Train_MaxReturn : 35.691925048828125
# Train_MinReturn : -104.12590026855469
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 627254
# TimeSinceStart : 458.82502031326294
# Training Loss : -593.4326782226562
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -25.75494956970215
# Eval_StdReturn : 18.311662673950195
# Eval_MaxReturn : -10.385112762451172
# Eval_MinReturn : -51.48984146118164
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -34.470497131347656
# Train_StdReturn : 25.114864349365234
# Train_MaxReturn : 7.978198051452637
# Train_MinReturn : -128.19973754882812
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 637371
# TimeSinceStart : 466.3405730724335
# Training Loss : -896.2647705078125
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 63 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -43.912967681884766
# Eval_StdReturn : 35.74985122680664
# Eval_MaxReturn : -2.4977521896362305
# Eval_MinReturn : -89.73357391357422
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -36.80461502075195
# Train_StdReturn : 24.039541244506836
# Train_MaxReturn : 11.683328628540039
# Train_MinReturn : -126.75209045410156
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 647488
# TimeSinceStart : 473.8956878185272
# Training Loss : -709.5393676757812
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 64 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -11.879444122314453
# Eval_StdReturn : 4.964500427246094
# Eval_MaxReturn : -7.453378677368164
# Eval_MinReturn : -18.812313079833984
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -29.242908477783203
# Train_StdReturn : 17.706714630126953
# Train_MaxReturn : 13.355389595031738
# Train_MinReturn : -62.06341552734375
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 657605
# TimeSinceStart : 481.42880630493164
# Training Loss : -790.0114135742188
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 65 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -34.818241119384766
# Eval_StdReturn : 28.7125301361084
# Eval_MaxReturn : 4.586850166320801
# Eval_MinReturn : -63.008602142333984
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -27.98491668701172
# Train_StdReturn : 21.667387008666992
# Train_MaxReturn : 32.426761627197266
# Train_MinReturn : -77.30553436279297
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 667722
# TimeSinceStart : 488.92589354515076
# Training Loss : -721.511962890625
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 66 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -24.509292602539062
# Eval_StdReturn : 16.641098022460938
# Eval_MaxReturn : -5.271322250366211
# Eval_MinReturn : -45.86772155761719
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -30.97556495666504
# Train_StdReturn : 23.491958618164062
# Train_MaxReturn : 26.238107681274414
# Train_MinReturn : -93.554443359375
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 677839
# TimeSinceStart : 496.399288892746
# Training Loss : -821.2862548828125
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 67 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -5.337949752807617
# Eval_StdReturn : 8.118424415588379
# Eval_MaxReturn : 6.08421516418457
# Eval_MinReturn : -12.055932998657227
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : -28.507164001464844
# Train_StdReturn : 16.08450698852539
# Train_MaxReturn : 12.726554870605469
# Train_MinReturn : -59.948875427246094
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 687956
# TimeSinceStart : 503.90846395492554
# Training Loss : -443.3274841308594
# Initial_DataCollection_AverageReturn : -87.20951843261719
# Done logging...
#
#
#
#
# ********** Iteration 68 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# ...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 135.71241760253906
# Eval_StdReturn : 13.621932983398438
# Eval_MaxReturn : 154.75906372070312
# Eval_MinReturn : 123.68817901611328
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 129.1221923828125
# Train_StdReturn : 16.772916793823242
# Train_MaxReturn : 168.70217895507812
# Train_MinReturn : 65.48744201660156
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 3910296
# TimeSinceStart : 2673.565006494522
# Training Loss : -1657.069091796875
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 78 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 130.9046630859375
# Eval_StdReturn : 9.911430358886719
# Eval_MaxReturn : 144.83311462402344
# Eval_MinReturn : 122.5791015625
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 127.53113555908203
# Train_StdReturn : 17.269702911376953
# Train_MaxReturn : 175.82733154296875
# Train_MinReturn : 48.53788375854492
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 3960428
# TimeSinceStart : 2707.8878688812256
# Training Loss : -1831.7808837890625
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 127.8714370727539
# Eval_StdReturn : 16.21527862548828
# Eval_MaxReturn : 141.2841033935547
# Eval_MinReturn : 105.05677795410156
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 129.5961456298828
# Train_StdReturn : 16.5833740234375
# Train_MaxReturn : 171.11801147460938
# Train_MinReturn : 73.37771606445312
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4010560
# TimeSinceStart : 2742.4309570789337
# Training Loss : -1618.485107421875
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 148.5399932861328
# Eval_StdReturn : 17.225481033325195
# Eval_MaxReturn : 166.26739501953125
# Eval_MinReturn : 125.20631408691406
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 139.37210083007812
# Train_StdReturn : 16.450183868408203
# Train_MaxReturn : 184.295654296875
# Train_MinReturn : 88.52874755859375
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4060692
# TimeSinceStart : 2776.7335267066956
# Training Loss : -1887.7435302734375
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 132.20896911621094
# Eval_StdReturn : 17.032424926757812
# Eval_MaxReturn : 155.88433837890625
# Eval_MinReturn : 116.52906036376953
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 138.7162322998047
# Train_StdReturn : 15.943629264831543
# Train_MaxReturn : 180.4142303466797
# Train_MinReturn : 80.197509765625
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4110824
# TimeSinceStart : 2810.927542448044
# Training Loss : -1798.6297607421875
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 141.34963989257812
# Eval_StdReturn : 2.00933575630188
# Eval_MaxReturn : 144.02301025390625
# Eval_MinReturn : 139.1787109375
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 139.16175842285156
# Train_StdReturn : 16.404617309570312
# Train_MaxReturn : 176.8851318359375
# Train_MinReturn : 80.52450561523438
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4160956
# TimeSinceStart : 2845.2543547153473
# Training Loss : -1551.06298828125
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 144.6112518310547
# Eval_StdReturn : 7.24009370803833
# Eval_MaxReturn : 150.30398559570312
# Eval_MinReturn : 134.39447021484375
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 135.7725830078125
# Train_StdReturn : 19.809520721435547
# Train_MaxReturn : 181.0902557373047
# Train_MinReturn : 51.030296325683594
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4211088
# TimeSinceStart : 2879.5746879577637
# Training Loss : -1521.156494140625
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 128.9360809326172
# Eval_StdReturn : 6.269035816192627
# Eval_MaxReturn : 135.63023376464844
# Eval_MinReturn : 120.55487060546875
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 137.2671356201172
# Train_StdReturn : 17.484439849853516
# Train_MaxReturn : 173.5989227294922
# Train_MinReturn : 76.38284301757812
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4261220
# TimeSinceStart : 2914.484988927841
# Training Loss : -1936.4254150390625
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 126.35912322998047
# Eval_StdReturn : 10.061091423034668
# Eval_MaxReturn : 138.73974609375
# Eval_MinReturn : 114.0960464477539
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 129.2921600341797
# Train_StdReturn : 18.294336318969727
# Train_MaxReturn : 177.95623779296875
# Train_MinReturn : 70.26557159423828
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4311352
# TimeSinceStart : 2948.723567008972
# Training Loss : -1768.5618896484375
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 147.97544860839844
# Eval_StdReturn : 18.081398010253906
# Eval_MaxReturn : 168.36160278320312
# Eval_MinReturn : 124.41416931152344
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 131.73486328125
# Train_StdReturn : 17.94658660888672
# Train_MaxReturn : 170.1961669921875
# Train_MinReturn : 57.3483772277832
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4361484
# TimeSinceStart : 2982.7564618587494
# Training Loss : -1633.6201171875
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 148.37722778320312
# Eval_StdReturn : 15.593090057373047
# Eval_MaxReturn : 165.62109375
# Eval_MinReturn : 127.85136413574219
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 140.31475830078125
# Train_StdReturn : 17.39244842529297
# Train_MaxReturn : 185.9952392578125
# Train_MinReturn : 60.64771270751953
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4411616
# TimeSinceStart : 3017.0050835609436
# Training Loss : -1941.0478515625
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 127.0353775024414
# Eval_StdReturn : 12.784557342529297
# Eval_MaxReturn : 143.98223876953125
# Eval_MinReturn : 113.10572814941406
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 140.34136962890625
# Train_StdReturn : 15.422707557678223
# Train_MaxReturn : 178.08132934570312
# Train_MinReturn : 81.40966796875
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4461748
# TimeSinceStart : 3051.615397453308
# Training Loss : -1367.065673828125
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 147.85769653320312
# Eval_StdReturn : 11.560013771057129
# Eval_MaxReturn : 157.52212524414062
# Eval_MinReturn : 131.606201171875
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 141.22813415527344
# Train_StdReturn : 16.825122833251953
# Train_MaxReturn : 188.41883850097656
# Train_MinReturn : 84.1364517211914
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4511880
# TimeSinceStart : 3086.0195019245148
# Training Loss : -755.9818115234375
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 146.67970275878906
# Eval_StdReturn : 7.883556365966797
# Eval_MaxReturn : 154.88720703125
# Eval_MinReturn : 136.04116821289062
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 143.8684844970703
# Train_StdReturn : 16.44379234313965
# Train_MaxReturn : 193.49073791503906
# Train_MinReturn : 90.67420196533203
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4562012
# TimeSinceStart : 3120.3226325511932
# Training Loss : -759.4002685546875
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 137.1990203857422
# Eval_StdReturn : 14.895127296447754
# Eval_MaxReturn : 151.69068908691406
# Eval_MinReturn : 116.71343994140625
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 145.20179748535156
# Train_StdReturn : 16.434621810913086
# Train_MaxReturn : 187.2874755859375
# Train_MinReturn : 92.47328186035156
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4612144
# TimeSinceStart : 3154.381633758545
# Training Loss : -956.05078125
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 123.8520736694336
# Eval_StdReturn : 10.12868881225586
# Eval_MaxReturn : 133.7108154296875
# Eval_MinReturn : 109.92328643798828
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 149.75927734375
# Train_StdReturn : 14.682774543762207
# Train_MaxReturn : 182.875
# Train_MinReturn : 98.0342025756836
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4662276
# TimeSinceStart : 3188.5125358104706
# Training Loss : -1364.0660400390625
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 128.09503173828125
# Eval_StdReturn : 4.384552001953125
# Eval_MaxReturn : 131.60824584960938
# Eval_MinReturn : 121.91355895996094
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 124.60596466064453
# Train_StdReturn : 17.104108810424805
# Train_MaxReturn : 172.22991943359375
# Train_MinReturn : 54.032623291015625
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4712408
# TimeSinceStart : 3222.6589035987854
# Training Loss : -1451.90478515625
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 137.52378845214844
# Eval_StdReturn : 3.1490819454193115
# Eval_MaxReturn : 140.75677490234375
# Eval_MinReturn : 133.2547607421875
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 130.45545959472656
# Train_StdReturn : 16.956165313720703
# Train_MaxReturn : 172.66964721679688
# Train_MinReturn : 55.730281829833984
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4762540
# TimeSinceStart : 3256.724339723587
# Training Loss : -1255.75048828125
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 133.23756408691406
# Eval_StdReturn : 6.062473297119141
# Eval_MaxReturn : 141.805908203125
# Eval_MinReturn : 128.69277954101562
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 143.01382446289062
# Train_StdReturn : 14.095970153808594
# Train_MaxReturn : 170.88287353515625
# Train_MinReturn : 91.16911315917969
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4812672
# TimeSinceStart : 3290.999502658844
# Training Loss : -1583.0343017578125
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 137.1157684326172
# Eval_StdReturn : 19.17025375366211
# Eval_MaxReturn : 159.21298217773438
# Eval_MinReturn : 112.46448516845703
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 135.59478759765625
# Train_StdReturn : 16.42142677307129
# Train_MaxReturn : 183.4050750732422
# Train_MinReturn : 83.68678283691406
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4862804
# TimeSinceStart : 3325.286273956299
# Training Loss : -843.3494873046875
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 139.2024383544922
# Eval_StdReturn : 11.103374481201172
# Eval_MaxReturn : 153.71197509765625
# Eval_MinReturn : 126.74840545654297
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 130.9490509033203
# Train_StdReturn : 15.876724243164062
# Train_MaxReturn : 178.04098510742188
# Train_MinReturn : 85.03459167480469
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4912936
# TimeSinceStart : 3359.6014630794525
# Training Loss : -1448.095947265625
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 148.60984802246094
# Eval_StdReturn : 8.850996971130371
# Eval_MaxReturn : 160.20993041992188
# Eval_MinReturn : 138.73687744140625
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 135.23696899414062
# Train_StdReturn : 15.874380111694336
# Train_MaxReturn : 177.67926025390625
# Train_MinReturn : 78.99935913085938
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 4963068
# TimeSinceStart : 3393.850643157959
# Training Loss : -1124.7158203125
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     50132 / 50000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 153.6920623779297
# Eval_StdReturn : 3.4502198696136475
# Eval_MaxReturn : 158.25323486328125
# Eval_MinReturn : 149.91053771972656
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 152.45458984375
# Train_StdReturn : 13.161468505859375
# Train_MaxReturn : 186.74891662597656
# Train_MinReturn : 109.48140716552734
# Train_AverageEpLen : 151.0
# Train_EnvstepsSoFar : 5013200
# TimeSinceStart : 3428.196269750595
# Training Loss : -1294.8583984375
# Initial_DataCollection_AverageReturn : -90.59088134765625
# Done logging...

# %%
def run_pendulum(r, b):
    # !python ./run_hw2.py  --env_name InvertedPendulum-v2 \
    --ep_len 1000 --discount 0.9 -n 100 -l 2 -s 64 -b {b} -lr {r} -rtg \
    --exp_name q2_b{b}_r{r}
    
for b in [10, 100, 200, 500, 800, 1000, 1500, 3000]:
    for lr in [0.005, .01, .02, .05, .1]:
        run_pendulum(lr, b)
# Out:
# ########################
# logging outputs to  /home/tomas/Documents/cs285/homework_fall2020/hw2/cs285/scripts/../../data/q2_b10_r0.005_InvertedPendulum-v2_26-09-2020_00-17-55
# ########################
# Using GPU id 0
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     13 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 11.485713958740234
# Eval_StdReturn : 7.00763463973999
# Eval_MaxReturn : 41.0
# Eval_MinReturn : 4.0
# Eval_AverageEpLen : 11.485714285714286
# Train_AverageReturn : 4.333333492279053
# Train_StdReturn : 0.4714045226573944
# Train_MaxReturn : 5.0
# Train_MinReturn : 4.0
# Train_AverageEpLen : 4.333333333333333
# Train_EnvstepsSoFar : 13
# TimeSinceStart : 0.20761346817016602
# Training Loss : 1.6568777561187744
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     18 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 16.00
# Eval_StdReturn : 8.049844741821289
# Eval_MaxReturn : 39.0
# Eval_MinReturn : 5.0
# Eval_AverageEpLen : 16.0
# Train_AverageReturn : 9.0
# Train_StdReturn : 2.0
# Train_MaxReturn : 11.0
# Train_MinReturn : 7.0
# Train_AverageEpLen : 9.0
# Train_EnvstepsSoFar : 31
# TimeSinceStart : 0.4085509777069092
# Training Loss : 0.27633965015411377
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     16 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 20.399999618530273
# Eval_StdReturn : 11.390347480773926
# Eval_MaxReturn : 47.0
# Eval_MinReturn : 5.0
# Eval_AverageEpLen : 20.4
# Train_AverageReturn : 16.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 16.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 16.0
# Train_EnvstepsSoFar : 47
# TimeSinceStart : 0.61081862449646
# Training Loss : -7.352017402648926
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     11 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 19.809524536132812
# Eval_StdReturn : 12.057872772216797
# Eval_MaxReturn : 57.0
# Eval_MinReturn : 8.0
# Eval_AverageEpLen : 19.80952380952381
# Train_AverageReturn : 11.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 11.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 11.0
# Train_EnvstepsSoFar : 58
# TimeSinceStart : 0.8216474056243896
# Training Loss : 0.5619400143623352
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     21 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 16.719999313354492
# Eval_StdReturn : 9.526888847351074
# Eval_MaxReturn : 46.0
# Eval_MinReturn : 6.0
# Eval_AverageEpLen : 16.72
# Train_AverageReturn : 10.5
# Train_StdReturn : 6.5
# Train_MaxReturn : 17.0
# Train_MinReturn : 4.0
# Train_AverageEpLen : 10.5
# Train_EnvstepsSoFar : 79
# TimeSinceStart : 1.0329246520996094
# Training Loss : -4.341571807861328
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     23 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 11.485713958740234
# Eval_StdReturn : 6.380198955535889
# Eval_MaxReturn : 38.0
# Eval_MinReturn : 4.0
# Eval_AverageEpLen : 11.485714285714286
# Train_AverageReturn : 23.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 23.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 23.0
# Train_EnvstepsSoFar : 102
# TimeSinceStart : 1.2402915954589844
# Training Loss : 1.2441651821136475
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     17 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 17.33333396911621
# Eval_StdReturn : 8.629729270935059
# Eval_MaxReturn : 35.0
# Eval_MinReturn : 5.0
# Eval_AverageEpLen : 17.333333333333332
# Train_AverageReturn : 8.5
# Train_StdReturn : 4.5
# Train_MaxReturn : 13.0
# Train_MinReturn : 4.0
# Train_AverageEpLen : 8.5
# Train_EnvstepsSoFar : 119
# TimeSinceStart : 1.4505155086517334
# Training Loss : -1.6050195693969727
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     12 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 12.53125
# Eval_StdReturn : 6.0929484367370605
# Eval_MaxReturn : 30.0
# Eval_MinReturn : 4.0
# Eval_AverageEpLen : 12.53125
# Train_AverageReturn : 12.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 12.0
# Train_MinReturn : 12.0
# Train_AverageEpLen : 12.0
# Train_EnvstepsSoFar : 131
# TimeSinceStart : 1.6507811546325684
# Training Loss : 0.21042537689208984
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     12 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 11.79411792755127
# Eval_StdReturn : 5.422064781188965
# Eval_MaxReturn : 27.0
# Eval_MinReturn : 5.0
# Eval_AverageEpLen : 11.794117647058824
# Train_AverageReturn : 12.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 12.0
# Train_MinReturn : 12.0
# Train_AverageEpLen : 12.0
# Train_EnvstepsSoFar : 143
# TimeSinceStart : 1.8569552898406982
# Training Loss : 3.124201536178589
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     12 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 14.642857551574707
# Eval_StdReturn : 7.621465682983398
# Eval_MaxReturn : 38.0
# Eval_MinReturn : 6.0
# Eval_AverageEpLen : 14.642857142857142
# Train_AverageReturn : 12.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 12.0
# Train_MinReturn : 12.0
# Train_AverageEpLen : 12.0
# Train_EnvstepsSoFar : 155
# TimeSinceStart : 2.0594499111175537
# Training Loss : 0.24257034063339233
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     11 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 26.733333587646484
# Eval_StdReturn : 10.388882637023926
# Eval_MaxReturn : 43.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 26.733333333333334
# Train_AverageReturn : 11.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 11.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 11.0
# Train_EnvstepsSoFar : 166
# TimeSinceStart : 2.2607266902923584
# Training Loss : -1.0989556312561035
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     27 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 47.70000076293945
# Eval_StdReturn : 31.502540588378906
# Eval_MaxReturn : 130.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 47.7
# Train_AverageReturn : 27.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 27.0
# Train_MinReturn : 27.0
# Train_AverageEpLen : 27.0
# Train_EnvstepsSoFar : 193
# TimeSinceStart : 2.499835968017578
# Training Loss : -3.850196599960327
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     89 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 34.58333206176758
# Eval_StdReturn : 15.934545516967773
# Eval_MaxReturn : 69.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 34.583333333333336
# Train_AverageReturn : 89.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 89.0
# Train_MinReturn : 89.0
# Train_AverageEpLen : 89.0
# Train_EnvstepsSoFar : 282
# TimeSinceStart : 2.7466752529144287
# Training Loss : -4.318760871887207
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     45 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 25.38888931274414
# Eval_StdReturn : 16.262222290039062
# Eval_MaxReturn : 72.0
# Eval_MinReturn : 6.0
# Eval_AverageEpLen : 25.38888888888889
# Train_AverageReturn : 45.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 45.0
# Train_MinReturn : 45.0
# Train_AverageEpLen : 45.0
# Train_EnvstepsSoFar : 327
# TimeSinceStart : 2.9834630489349365
# Training Loss : 1.2473549842834473
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     13 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 23.00
# Eval_StdReturn : 13.848384857177734
# Eval_MaxReturn : 49.0
# Eval_MinReturn : 6.0
# Eval_AverageEpLen : 23.0
# Train_AverageReturn : 13.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 13.0
# Train_MinReturn : 13.0
# Train_AverageEpLen : 13.0
# Train_EnvstepsSoFar : 340
# TimeSinceStart : 3.1873013973236084
# Training Loss : 0.0990290641784668
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     52 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 17.20833396911621
# Eval_StdReturn : 7.382293701171875
# Eval_MaxReturn : 38.0
# Eval_MinReturn : 6.0
# Eval_AverageEpLen : 17.208333333333332
# Train_AverageReturn : 52.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 52.0
# Train_MinReturn : 52.0
# Train_AverageEpLen : 52.0
# Train_EnvstepsSoFar : 392
# TimeSinceStart : 3.410646677017212
# Training Loss : -3.189304828643799
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     21 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 16.70833396911621
# Eval_StdReturn : 6.882823467254639
# Eval_MaxReturn : 34.0
# Eval_MinReturn : 7.0
# Eval_AverageEpLen : 16.708333333333332
# Train_AverageReturn : 10.5
# Train_StdReturn : 1.5
# Train_MaxReturn : 12.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 10.5
# Train_EnvstepsSoFar : 413
# TimeSinceStart : 3.6125521659851074
# Training Loss : -1.6448676586151123
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     10 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 15.461538314819336
# Eval_StdReturn : 7.333961009979248
# Eval_MaxReturn : 38.0
# Eval_MinReturn : 5.0
# Eval_AverageEpLen : 15.461538461538462
# Train_AverageReturn : 10.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 10.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 10.0
# Train_EnvstepsSoFar : 423
# TimeSinceStart : 3.8141467571258545
# Training Loss : 1.005807638168335
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     10 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 14.88888931274414
# Eval_StdReturn : 6.838525772094727
# Eval_MaxReturn : 39.0
# Eval_MinReturn : 6.0
# Eval_AverageEpLen : 14.88888888888889
# Train_AverageReturn : 10.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 10.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 10.0
# Train_EnvstepsSoFar : 433
# TimeSinceStart : 4.014582633972168
# Training Loss : -3.458137273788452
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     24 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 20.399999618530273
# Eval_StdReturn : 7.838367462158203
# Eval_MaxReturn : 37.0
# Eval_MinReturn : 7.0
# Eval_AverageEpLen : 20.4
# Train_AverageReturn : 24.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 24.0
# Train_MinReturn : 24.0
# Train_AverageEpLen : 24.0
# Train_EnvstepsSoFar : 457
# TimeSinceStart : 4.2361366748809814
# Training Loss : -0.19108939170837402
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     16 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 22.421052932739258
# Eval_StdReturn : 12.987102508544922
# Eval_MaxReturn : 64.0
# Eval_MinReturn : 6.0
# Eval_AverageEpLen : 22.42105263157895
# Train_AverageReturn : 16.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 16.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 16.0
# Train_EnvstepsSoFar : 473
# TimeSinceStart : 4.448254823684692
# Training Loss : 0.7637791633605957
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     13 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 24.647058486938477
# Eval_StdReturn : 16.566946029663086
# Eval_MaxReturn : 79.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 24.647058823529413
# Train_AverageReturn : 13.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 13.0
# Train_MinReturn : 13.0
# Train_AverageEpLen : 13.0
# Train_EnvstepsSoFar : 486
# TimeSinceStart : 4.657513856887817
# Training Loss : -0.3527895212173462
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     20 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 19.904762268066406
# Eval_StdReturn : 12.382416725158691
# Eval_MaxReturn : 66.0
# Eval_MinReturn : 4.0
# Eval_AverageEpLen : 19.904761904761905
# Train_AverageReturn : 20.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 20.0
# Train_MinReturn : 20.0
# Train_AverageEpLen : 20.0
# Train_EnvstepsSoFar : 506
# TimeSinceStart : 4.8678717613220215
# Training Loss : 0.6091784238815308
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     34 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 25.6875
# Eval_StdReturn : 15.778619766235352
# Eval_MaxReturn : 71.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 25.6875
# Train_AverageReturn : 34.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 34.0
# Train_MinReturn : 34.0
# Train_AverageEpLen : 34.0
# Train_EnvstepsSoFar : 540
# TimeSinceStart : 5.080801010131836
# Training Loss : 3.2453689575195312
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     23 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 35.83333206176758
# Eval_StdReturn : 21.835878372192383
# Eval_MaxReturn : 88.0
# Eval_MinReturn : 8.0
# Eval_AverageEpLen : 35.833333333333336
# Train_AverageReturn : 23.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 23.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 23.0
# Train_EnvstepsSoFar : 563
# TimeSinceStart : 5.298550605773926
# Training Loss : -0.279771089553833
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     13 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 33.07692337036133
# Eval_StdReturn : 16.93181610107422
# Eval_MaxReturn : 63.0
# Eval_MinReturn : 7.0
# Eval_AverageEpLen : 33.07692307692308
# Train_AverageReturn : 13.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 13.0
# Train_MinReturn : 13.0
# Train_AverageEpLen : 13.0
# Train_EnvstepsSoFar : 576
# TimeSinceStart : 5.509671211242676
# Training Loss : -1.1914376020431519
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     57 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 30.769229888916016
# Eval_StdReturn : 18.60171127319336
# Eval_MaxReturn : 71.0
# Eval_MinReturn : 7.0
# Eval_AverageEpLen : 30.76923076923077
# Train_AverageReturn : 57.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 57.0
# Train_MinReturn : 57.0
# Train_AverageEpLen : 57.0
# Train_EnvstepsSoFar : 633
# TimeSinceStart : 5.734633684158325
# Training Loss : -0.7478094100952148
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     19 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 43.900001525878906
# Eval_StdReturn : 29.81090545654297
# Eval_MaxReturn : 100.0
# Eval_MinReturn : 4.0
# Eval_AverageEpLen : 43.9
# Train_AverageReturn : 19.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 19.0
# Train_MinReturn : 19.0
# Train_AverageEpLen : 19.0
# Train_EnvstepsSoFar : 652
# TimeSinceStart : 5.954610347747803
# Training Loss : 4.626725196838379
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     20 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 52.875
# Eval_StdReturn : 50.3870964050293
# Eval_MaxReturn : 168.0
# Eval_MinReturn : 8.0
# Eval_AverageEpLen : 52.875
# Train_AverageReturn : 20.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 20.0
# Train_MinReturn : 20.0
# Train_AverageEpLen : 20.0
# Train_EnvstepsSoFar : 672
# TimeSinceStart : 6.167987585067749
# Training Loss : -5.907919883728027
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     31 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 33.91666793823242
# Eval_StdReturn : 15.739855766296387
# Eval_MaxReturn : 58.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 33.916666666666664
# Train_AverageReturn : 31.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 31.0
# Train_MinReturn : 31.0
# Train_AverageEpLen : 31.0
# Train_EnvstepsSoFar : 703
# TimeSinceStart : 6.379459619522095
# Training Loss : -2.106109619140625
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     35 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 54.375
# Eval_StdReturn : 21.464723587036133
# Eval_MaxReturn : 83.0
# Eval_MinReturn : 16.0
# Eval_AverageEpLen : 54.375
# Train_AverageReturn : 35.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 35.0
# Train_MinReturn : 35.0
# Train_AverageEpLen : 35.0
# Train_EnvstepsSoFar : 738
# TimeSinceStart : 6.604002952575684
# Training Loss : -5.228735446929932
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     25 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 50.50
# Eval_StdReturn : 14.815532684326172
# Eval_MaxReturn : 76.0
# Eval_MinReturn : 31.0
# Eval_AverageEpLen : 50.5
# Train_AverageReturn : 25.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 25.0
# Train_MinReturn : 25.0
# Train_AverageEpLen : 25.0
# Train_EnvstepsSoFar : 763
# TimeSinceStart : 6.8164215087890625
# Training Loss : -12.181804656982422
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     55 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 53.125
# Eval_StdReturn : 19.763839721679688
# Eval_MaxReturn : 90.0
# Eval_MinReturn : 31.0
# Eval_AverageEpLen : 53.125
# Train_AverageReturn : 55.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 55.0
# Train_MinReturn : 55.0
# Train_AverageEpLen : 55.0
# Train_EnvstepsSoFar : 818
# TimeSinceStart : 7.050296068191528
# Training Loss : 11.64595890045166
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     58 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 59.28571319580078
# Eval_StdReturn : 24.667585372924805
# Eval_MaxReturn : 100.0
# Eval_MinReturn : 39.0
# Eval_AverageEpLen : 59.285714285714285
# Train_AverageReturn : 58.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 58.0
# Train_MinReturn : 58.0
# Train_AverageEpLen : 58.0
# Train_EnvstepsSoFar : 876
# TimeSinceStart : 7.279238939285278
# Training Loss : -3.2439184188842773
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     62 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 57.28571319580078
# Eval_StdReturn : 21.062589645385742
# Eval_MaxReturn : 90.0
# Eval_MinReturn : 18.0
# Eval_AverageEpLen : 57.285714285714285
# Train_AverageReturn : 62.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 62.0
# Train_MinReturn : 62.0
# Train_AverageEpLen : 62.0
# Train_EnvstepsSoFar : 938
# TimeSinceStart : 7.501252889633179
# Training Loss : 2.863554000854492
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     54 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 71.42857360839844
# Eval_StdReturn : 37.74673843383789
# Eval_MaxReturn : 147.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 71.42857142857143
# Train_AverageReturn : 54.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 54.0
# Train_MinReturn : 54.0
# Train_AverageEpLen : 54.0
# Train_EnvstepsSoFar : 992
# TimeSinceStart : 7.770368814468384
# Training Loss : -4.151561260223389
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     60 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 65.57142639160156
# Eval_StdReturn : 43.22319793701172
# Eval_MaxReturn : 143.0
# Eval_MinReturn : 19.0
# Eval_AverageEpLen : 65.57142857142857
# Train_AverageReturn : 60.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 60.0
# Train_MinReturn : 60.0
# Train_AverageEpLen : 60.0
# Train_EnvstepsSoFar : 1052
# TimeSinceStart : 8.015480995178223
# Training Loss : -1.4901952743530273
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     50 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 96.5999984741211
# Eval_StdReturn : 53.570884704589844
# Eval_MaxReturn : 154.0
# Eval_MinReturn : 20.0
# Eval_AverageEpLen : 96.6
# Train_AverageReturn : 50.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 50.0
# Train_MinReturn : 50.0
# Train_AverageEpLen : 50.0
# Train_EnvstepsSoFar : 1102
# TimeSinceStart : 8.266416788101196
# Training Loss : -2.051321506500244
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     65 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.00
# Eval_StdReturn : 21.840330123901367
# Eval_MaxReturn : 73.0
# Eval_MinReturn : 12.0
# Eval_AverageEpLen : 41.0
# Train_AverageReturn : 65.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 65.0
# Train_MinReturn : 65.0
# Train_AverageEpLen : 65.0
# Train_EnvstepsSoFar : 1167
# TimeSinceStart : 8.493018627166748
# Training Loss : -2.1662492752075195
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     33 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 37.6363639831543
# Eval_StdReturn : 24.922691345214844
# Eval_MaxReturn : 91.0
# Eval_MinReturn : 7.0
# Eval_AverageEpLen : 37.63636363636363
# Train_AverageReturn : 33.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 33.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 33.0
# Train_EnvstepsSoFar : 1200
# TimeSinceStart : 8.708210229873657
# Training Loss : -1.0226240158081055
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     63 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 28.46666717529297
# Eval_StdReturn : 16.7087459564209
# Eval_MaxReturn : 64.0
# Eval_MinReturn : 5.0
# Eval_AverageEpLen : 28.466666666666665
# Train_AverageReturn : 63.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 63.0
# Train_MinReturn : 63.0
# Train_AverageEpLen : 63.0
# Train_EnvstepsSoFar : 1263
# TimeSinceStart : 8.942505359649658
# Training Loss : 2.0816383361816406
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     45 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 18.29166603088379
# Eval_StdReturn : 11.681463241577148
# Eval_MaxReturn : 46.0
# Eval_MinReturn : 6.0
# Eval_AverageEpLen : 18.291666666666668
# Train_AverageReturn : 45.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 45.0
# Train_MinReturn : 45.0
# Train_AverageEpLen : 45.0
# Train_EnvstepsSoFar : 1308
# TimeSinceStart : 9.17511796951294
# Training Loss : -5.307736396789551
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     21 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 18.18181800842285
# Eval_StdReturn : 11.68385124206543
# Eval_MaxReturn : 47.0
# Eval_MinReturn : 7.0
# Eval_AverageEpLen : 18.181818181818183
# Train_AverageReturn : 21.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 21.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 21.0
# Train_EnvstepsSoFar : 1329
# TimeSinceStart : 9.37787675857544
# Training Loss : -4.227142333984375
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     10 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 16.200000762939453
# Eval_StdReturn : 10.357605934143066
# Eval_MaxReturn : 46.0
# Eval_MinReturn : 6.0
# Eval_AverageEpLen : 16.2
# Train_AverageReturn : 10.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 10.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 10.0
# Train_EnvstepsSoFar : 1339
# TimeSinceStart : 9.577555179595947
# Training Loss : 1.6473498344421387
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     17 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 17.04166603088379
# Eval_StdReturn : 7.651139259338379
# Eval_MaxReturn : 37.0
# Eval_MinReturn : 6.0
# Eval_AverageEpLen : 17.041666666666668
# Train_AverageReturn : 17.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 17.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 17.0
# Train_EnvstepsSoFar : 1356
# TimeSinceStart : 9.785722732543945
# Training Loss : -1.785658836364746
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     12 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 21.210525512695312
# Eval_StdReturn : 11.432083129882812
# Eval_MaxReturn : 47.0
# Eval_MinReturn : 8.0
# Eval_AverageEpLen : 21.210526315789473
# Train_AverageReturn : 12.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 12.0
# Train_MinReturn : 12.0
# Train_AverageEpLen : 12.0
# Train_EnvstepsSoFar : 1368
# TimeSinceStart : 9.983775854110718
# Training Loss : -1.2892429828643799
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     16 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 19.571428298950195
# Eval_StdReturn : 6.191941261291504
# Eval_MaxReturn : 30.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 19.571428571428573
# Train_AverageReturn : 16.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 16.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 16.0
# Train_EnvstepsSoFar : 1384
# TimeSinceStart : 10.188454866409302
# Training Loss : -0.45812320709228516
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     50 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 17.45833396911621
# Eval_StdReturn : 7.916118621826172
# Eval_MaxReturn : 37.0
# Eval_MinReturn : 7.0
# Eval_AverageEpLen : 17.458333333333332
# Train_AverageReturn : 50.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 50.0
# Train_MinReturn : 50.0
# Train_AverageEpLen : 50.0
# Train_EnvstepsSoFar : 1434
# TimeSinceStart : 10.415210247039795
# Training Loss : -4.878808975219727
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     23 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 23.823530197143555
# Eval_StdReturn : 12.917089462280273
# Eval_MaxReturn : 53.0
# Eval_MinReturn : 7.0
# Eval_AverageEpLen : 23.823529411764707
# Train_AverageReturn : 23.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 23.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 23.0
# Train_EnvstepsSoFar : 1457
# TimeSinceStart : 10.619684934616089
# Training Loss : -6.752804756164551
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     16 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 30.066667556762695
# Eval_StdReturn : 14.712655067443848
# Eval_MaxReturn : 61.0
# Eval_MinReturn : 12.0
# Eval_AverageEpLen : 30.066666666666666
# Train_AverageReturn : 16.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 16.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 16.0
# Train_EnvstepsSoFar : 1473
# TimeSinceStart : 10.841356754302979
# Training Loss : -3.3572282791137695
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     22 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 24.235294342041016
# Eval_StdReturn : 13.36161994934082
# Eval_MaxReturn : 58.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 24.235294117647058
# Train_AverageReturn : 22.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 22.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 22.0
# Train_EnvstepsSoFar : 1495
# TimeSinceStart : 11.045126676559448
# Training Loss : -0.8116278648376465
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     24 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 31.00
# Eval_StdReturn : 11.275764465332031
# Eval_MaxReturn : 55.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 31.0
# Train_AverageReturn : 24.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 24.0
# Train_MinReturn : 24.0
# Train_AverageEpLen : 24.0
# Train_EnvstepsSoFar : 1519
# TimeSinceStart : 11.261656999588013
# Training Loss : -3.232002019882202
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     17 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 34.08333206176758
# Eval_StdReturn : 20.790454864501953
# Eval_MaxReturn : 74.0
# Eval_MinReturn : 5.0
# Eval_AverageEpLen : 34.083333333333336
# Train_AverageReturn : 17.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 17.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 17.0
# Train_EnvstepsSoFar : 1536
# TimeSinceStart : 11.462043285369873
# Training Loss : -4.4818010330200195
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     61 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 37.09090805053711
# Eval_StdReturn : 16.86553382873535
# Eval_MaxReturn : 72.0
# Eval_MinReturn : 13.0
# Eval_AverageEpLen : 37.09090909090909
# Train_AverageReturn : 61.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 61.0
# Train_MinReturn : 61.0
# Train_AverageEpLen : 61.0
# Train_EnvstepsSoFar : 1597
# TimeSinceStart : 11.688293695449829
# Training Loss : -6.804073333740234
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     27 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 53.375
# Eval_StdReturn : 16.755128860473633
# Eval_MaxReturn : 76.0
# Eval_MinReturn : 28.0
# Eval_AverageEpLen : 53.375
# Train_AverageReturn : 27.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 27.0
# Train_MinReturn : 27.0
# Train_AverageEpLen : 27.0
# Train_EnvstepsSoFar : 1624
# TimeSinceStart : 11.901015520095825
# Training Loss : 8.389283180236816
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     44 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 54.44444274902344
# Eval_StdReturn : 24.68067741394043
# Eval_MaxReturn : 103.0
# Eval_MinReturn : 19.0
# Eval_AverageEpLen : 54.44444444444444
# Train_AverageReturn : 44.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 44.0
# Train_MinReturn : 44.0
# Train_AverageEpLen : 44.0
# Train_EnvstepsSoFar : 1668
# TimeSinceStart : 12.151201248168945
# Training Loss : 8.729676246643066
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     44 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 80.5999984741211
# Eval_StdReturn : 42.495174407958984
# Eval_MaxReturn : 149.0
# Eval_MinReturn : 40.0
# Eval_AverageEpLen : 80.6
# Train_AverageReturn : 44.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 44.0
# Train_MinReturn : 44.0
# Train_AverageEpLen : 44.0
# Train_EnvstepsSoFar : 1712
# TimeSinceStart : 12.362877130508423
# Training Loss : 1.402761459350586
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     72 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 130.5
# Eval_StdReturn : 59.66783142089844
# Eval_MaxReturn : 231.0
# Eval_MinReturn : 76.0
# Eval_AverageEpLen : 130.5
# Train_AverageReturn : 72.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 72.0
# Train_MinReturn : 72.0
# Train_AverageEpLen : 72.0
# Train_EnvstepsSoFar : 1784
# TimeSinceStart : 12.640605449676514
# Training Loss : -6.0662736892700195
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     67 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 83.80000305175781
# Eval_StdReturn : 46.70075225830078
# Eval_MaxReturn : 174.0
# Eval_MinReturn : 48.0
# Eval_AverageEpLen : 83.8
# Train_AverageReturn : 67.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 67.0
# Train_MinReturn : 67.0
# Train_AverageEpLen : 67.0
# Train_EnvstepsSoFar : 1851
# TimeSinceStart : 12.878671407699585
# Training Loss : -3.8480682373046875
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     98 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 108.0
# Eval_StdReturn : 42.11294174194336
# Eval_MaxReturn : 159.0
# Eval_MinReturn : 63.0
# Eval_AverageEpLen : 108.0
# Train_AverageReturn : 98.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 98.0
# Train_MinReturn : 98.0
# Train_AverageEpLen : 98.0
# Train_EnvstepsSoFar : 1949
# TimeSinceStart : 13.139576435089111
# Training Loss : -3.012727737426758
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     100 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 120.75
# Eval_StdReturn : 45.576171875
# Eval_MaxReturn : 166.0
# Eval_MinReturn : 59.0
# Eval_AverageEpLen : 120.75
# Train_AverageReturn : 100.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 100.0
# Train_MinReturn : 100.0
# Train_AverageEpLen : 100.0
# Train_EnvstepsSoFar : 2049
# TimeSinceStart : 13.422115325927734
# Training Loss : 2.4476256370544434
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     48 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 82.00
# Eval_StdReturn : 42.59107971191406
# Eval_MaxReturn : 160.0
# Eval_MinReturn : 38.0
# Eval_AverageEpLen : 82.0
# Train_AverageReturn : 48.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 48.0
# Train_MinReturn : 48.0
# Train_AverageEpLen : 48.0
# Train_EnvstepsSoFar : 2097
# TimeSinceStart : 13.640053033828735
# Training Loss : -0.9805841445922852
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
# At timestep:     61 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 122.0
# Eval_StdReturn : 29.504236221313477
# Eval_MaxReturn : 162.0
# Eval_MinReturn : 86.0
# Eval_AverageEpLen : 122.0
# Train_AverageReturn : 61.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 61.0
# Train_MinReturn : 61.0
# Train_AverageEpLen : 61.0
# Train_EnvstepsSoFar : 2158
# TimeSinceStart : 13.90384316444397
# Training Loss : -4.483699798583984
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 63 ************
#
# Collecting data to be used for training...
# At timestep:     70 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 146.0
# Eval_StdReturn : 41.533119201660156
# Eval_MaxReturn : 209.0
# Eval_MinReturn : 103.0
# Eval_AverageEpLen : 146.0
# Train_AverageReturn : 70.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 70.0
# Train_MinReturn : 70.0
# Train_AverageEpLen : 70.0
# Train_EnvstepsSoFar : 2228
# TimeSinceStart : 14.214387655258179
# Training Loss : -7.512387275695801
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 64 ************
#
# Collecting data to be used for training...
# At timestep:     47 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 254.5
# Eval_StdReturn : 146.5
# Eval_MaxReturn : 401.0
# Eval_MinReturn : 108.0
# Eval_AverageEpLen : 254.5
# Train_AverageReturn : 47.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 47.0
# Train_MinReturn : 47.0
# Train_AverageEpLen : 47.0
# Train_EnvstepsSoFar : 2275
# TimeSinceStart : 14.476482152938843
# Training Loss : 4.403829574584961
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 65 ************
#
# Collecting data to be used for training...
# At timestep:     86 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 114.0
# Eval_StdReturn : 43.26083755493164
# Eval_MaxReturn : 169.0
# Eval_MinReturn : 53.0
# Eval_AverageEpLen : 114.0
# Train_AverageReturn : 86.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 86.0
# Train_MinReturn : 86.0
# Train_AverageEpLen : 86.0
# Train_EnvstepsSoFar : 2361
# TimeSinceStart : 14.738669633865356
# Training Loss : -6.3308424949646
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 66 ************
#
# Collecting data to be used for training...
# At timestep:     92 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 111.75
# Eval_StdReturn : 45.20716094970703
# Eval_MaxReturn : 181.0
# Eval_MinReturn : 69.0
# Eval_AverageEpLen : 111.75
# Train_AverageReturn : 92.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 92.0
# Train_MinReturn : 92.0
# Train_AverageEpLen : 92.0
# Train_EnvstepsSoFar : 2453
# TimeSinceStart : 14.995877027511597
# Training Loss : -18.977245330810547
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 67 ************
#
# Collecting data to be used for training...
# At timestep:     77 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 95.80000305175781
# Eval_StdReturn : 29.68096923828125
# Eval_MaxReturn : 126.0
# Eval_MinReturn : 48.0
# Eval_AverageEpLen : 95.8
# Train_AverageReturn : 77.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 77.0
# Train_MinReturn : 77.0
# Train_AverageEpLen : 77.0
# Train_EnvstepsSoFar : 2530
# TimeSinceStart : 15.261149406433105
# Training Loss : 4.479844570159912
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 68 ************
#
# Collecting data to be used for training...
# At timestep:     116 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 75.83333587646484
# Eval_StdReturn : 28.538959503173828
# Eval_MaxReturn : 123.0
# Eval_MinReturn : 39.0
# Eval_AverageEpLen : 75.83333333333333
# Train_AverageReturn : 116.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 116.0
# Train_MinReturn : 116.0
# Train_AverageEpLen : 116.0
# Train_EnvstepsSoFar : 2646
# TimeSinceStart : 15.53949785232544
# Training Loss : -10.404881477355957
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 69 ************
#
# Collecting data to be used for training...
# At timestep:     55 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 69.00
# Eval_StdReturn : 15.448840141296387
# Eval_MaxReturn : 86.0
# Eval_MinReturn : 41.0
# Eval_AverageEpLen : 69.0
# Train_AverageReturn : 55.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 55.0
# Train_MinReturn : 55.0
# Train_AverageEpLen : 55.0
# Train_EnvstepsSoFar : 2701
# TimeSinceStart : 15.766080141067505
# Training Loss : 6.843666076660156
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 70 ************
#
# Collecting data to be used for training...
# At timestep:     89 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 63.42856979370117
# Eval_StdReturn : 29.13935661315918
# Eval_MaxReturn : 98.0
# Eval_MinReturn : 8.0
# Eval_AverageEpLen : 63.42857142857143
# Train_AverageReturn : 89.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 89.0
# Train_MinReturn : 89.0
# Train_AverageEpLen : 89.0
# Train_EnvstepsSoFar : 2790
# TimeSinceStart : 16.02126383781433
# Training Loss : 2.829038619995117
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 71 ************
#
# Collecting data to be used for training...
# At timestep:     91 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 71.00
# Eval_StdReturn : 40.35910415649414
# Eval_MaxReturn : 135.0
# Eval_MinReturn : 6.0
# Eval_AverageEpLen : 71.0
# Train_AverageReturn : 91.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 91.0
# Train_MinReturn : 91.0
# Train_AverageEpLen : 91.0
# Train_EnvstepsSoFar : 2881
# TimeSinceStart : 16.30601716041565
# Training Loss : 4.600252151489258
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 72 ************
#
# Collecting data to be used for training...
# At timestep:     37 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 60.85714340209961
# Eval_StdReturn : 22.490814208984375
# Eval_MaxReturn : 102.0
# Eval_MinReturn : 34.0
# Eval_AverageEpLen : 60.857142857142854
# Train_AverageReturn : 37.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 37.0
# Train_MinReturn : 37.0
# Train_AverageEpLen : 37.0
# Train_EnvstepsSoFar : 2918
# TimeSinceStart : 16.52634072303772
# Training Loss : 3.130004405975342
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 73 ************
#
# Collecting data to be used for training...
# At timestep:     39 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 46.20000076293945
# Eval_StdReturn : 27.028873443603516
# Eval_MaxReturn : 91.0
# Eval_MinReturn : 14.0
# Eval_AverageEpLen : 46.2
# Train_AverageReturn : 39.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 39.0
# Train_MinReturn : 39.0
# Train_AverageEpLen : 39.0
# Train_EnvstepsSoFar : 2957
# TimeSinceStart : 16.76760196685791
# Training Loss : -3.5243000984191895
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 74 ************
#
# Collecting data to be used for training...
# At timestep:     99 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 67.66666412353516
# Eval_StdReturn : 35.2877082824707
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 33.0
# Eval_AverageEpLen : 67.66666666666667
# Train_AverageReturn : 99.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 99.0
# Train_MinReturn : 99.0
# Train_AverageEpLen : 99.0
# Train_EnvstepsSoFar : 3056
# TimeSinceStart : 17.013636827468872
# Training Loss : 3.290480136871338
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 75 ************
#
# Collecting data to be used for training...
# At timestep:     19 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 55.25
# Eval_StdReturn : 24.953706741333008
# Eval_MaxReturn : 103.0
# Eval_MinReturn : 14.0
# Eval_AverageEpLen : 55.25
# Train_AverageReturn : 19.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 19.0
# Train_MinReturn : 19.0
# Train_AverageEpLen : 19.0
# Train_EnvstepsSoFar : 3075
# TimeSinceStart : 17.23815941810608
# Training Loss : 0.7879971265792847
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 76 ************
#
# Collecting data to be used for training...
# At timestep:     34 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 46.11111068725586
# Eval_StdReturn : 22.06779670715332
# Eval_MaxReturn : 88.0
# Eval_MinReturn : 16.0
# Eval_AverageEpLen : 46.111111111111114
# Train_AverageReturn : 34.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 34.0
# Train_MinReturn : 34.0
# Train_AverageEpLen : 34.0
# Train_EnvstepsSoFar : 3109
# TimeSinceStart : 17.45364260673523
# Training Loss : -1.780548095703125
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 77 ************
#
# Collecting data to be used for training...
# At timestep:     88 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 58.375
# Eval_StdReturn : 18.907257080078125
# Eval_MaxReturn : 88.0
# Eval_MinReturn : 37.0
# Eval_AverageEpLen : 58.375
# Train_AverageReturn : 88.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 88.0
# Train_MinReturn : 88.0
# Train_AverageEpLen : 88.0
# Train_EnvstepsSoFar : 3197
# TimeSinceStart : 17.726064920425415
# Training Loss : -33.17644119262695
# Initial_DataCollection_AverageReturn : 4.333333492279053
# Done logging...
#
#
#
#
# ********** Iteration 78 ************
#
# Collecting data to be used for training...
# At timestep:     113 / 10
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 62.14285659790039
# Eval_StdReturn : 37.2613525390625
# Eval_MaxReturn : 132.0
# ...
# Training Loss : -0.45883941650390625
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 75 ************
#
# Collecting data to be used for training...
# At timestep:     3118 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 51.55555725097656
# Eval_StdReturn : 23.809946060180664
# Eval_MaxReturn : 86.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 51.55555555555556
# Train_AverageReturn : 135.56521606445312
# Train_StdReturn : 106.1470718383789
# Train_MaxReturn : 427.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 135.56521739130434
# Train_EnvstepsSoFar : 234742
# TimeSinceStart : 205.8226499557495
# Training Loss : -31.872798919677734
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 76 ************
#
# Collecting data to be used for training...
# At timestep:     3007 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 132.0
# Eval_StdReturn : 104.76068115234375
# Eval_MaxReturn : 328.0
# Eval_MinReturn : 50.0
# Eval_AverageEpLen : 132.0
# Train_AverageReturn : 34.96511459350586
# Train_StdReturn : 30.184490203857422
# Train_MaxReturn : 132.0
# Train_MinReturn : 5.0
# Train_AverageEpLen : 34.96511627906977
# Train_EnvstepsSoFar : 237749
# TimeSinceStart : 207.79388451576233
# Training Loss : -9.000921249389648
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 77 ************
#
# Collecting data to be used for training...
# At timestep:     3041 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 60.57143020629883
# Eval_StdReturn : 17.442617416381836
# Eval_MaxReturn : 88.0
# Eval_MinReturn : 39.0
# Eval_AverageEpLen : 60.57142857142857
# Train_AverageReturn : 104.86206817626953
# Train_StdReturn : 94.92926788330078
# Train_MaxReturn : 452.0
# Train_MinReturn : 38.0
# Train_AverageEpLen : 104.86206896551724
# Train_EnvstepsSoFar : 240790
# TimeSinceStart : 209.9619915485382
# Training Loss : 27.61927032470703
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 78 ************
#
# Collecting data to be used for training...
# At timestep:     3035 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 687.00
# Eval_StdReturn : 313.0
# Eval_MaxReturn : 1000.0
# Eval_MinReturn : 374.0
# Eval_AverageEpLen : 687.0
# Train_AverageReturn : 48.95161437988281
# Train_StdReturn : 19.68250274658203
# Train_MaxReturn : 148.0
# Train_MinReturn : 26.0
# Train_AverageEpLen : 48.95161290322581
# Train_EnvstepsSoFar : 243825
# TimeSinceStart : 212.25545454025269
# Training Loss : 29.749126434326172
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
# At timestep:     3000 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 37.3636360168457
# Eval_StdReturn : 19.485530853271484
# Eval_MaxReturn : 70.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 37.36363636363637
# Train_AverageReturn : 1000.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 1000.0
# Train_MinReturn : 1000.0
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 246825
# TimeSinceStart : 216.4463963508606
# Training Loss : -78.92816162109375
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     3009 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 25.4375
# Eval_StdReturn : 22.66596794128418
# Eval_MaxReturn : 99.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 25.4375
# Train_AverageReturn : 35.82143020629883
# Train_StdReturn : 27.811080932617188
# Train_MaxReturn : 114.0
# Train_MinReturn : 6.0
# Train_AverageEpLen : 35.82142857142857
# Train_EnvstepsSoFar : 249834
# TimeSinceStart : 218.27130031585693
# Training Loss : 27.73642921447754
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     3010 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 1000.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 1000.0
# Eval_MinReturn : 1000.0
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 21.970802307128906
# Train_StdReturn : 17.29855728149414
# Train_MaxReturn : 125.0
# Train_MinReturn : 5.0
# Train_AverageEpLen : 21.970802919708028
# Train_EnvstepsSoFar : 252844
# TimeSinceStart : 220.3106245994568
# Training Loss : 2.0844783782958984
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     3000 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 1000.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 1000.0
# Eval_MinReturn : 1000.0
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 1000.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 1000.0
# Train_MinReturn : 1000.0
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 255844
# TimeSinceStart : 224.69837427139282
# Training Loss : -4.637672424316406
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     3000 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 36.45454406738281
# Eval_StdReturn : 18.317222595214844
# Eval_MaxReturn : 81.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 36.45454545454545
# Train_AverageReturn : 1000.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 1000.0
# Train_MinReturn : 1000.0
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 258844
# TimeSinceStart : 228.85547280311584
# Training Loss : -7.070955276489258
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     3035 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 1000.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 1000.0
# Eval_MinReturn : 1000.0
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 54.19643020629883
# Train_StdReturn : 51.1546745300293
# Train_MaxReturn : 234.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 54.19642857142857
# Train_EnvstepsSoFar : 261879
# TimeSinceStart : 231.06130838394165
# Training Loss : -64.95301818847656
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     3000 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 1000.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 1000.0
# Eval_MinReturn : 1000.0
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 1000.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 1000.0
# Train_MinReturn : 1000.0
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 264879
# TimeSinceStart : 235.43067121505737
# Training Loss : 54.97781753540039
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     3000 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 27.66666603088379
# Eval_StdReturn : 11.288146018981934
# Eval_MaxReturn : 57.0
# Eval_MinReturn : 13.0
# Eval_AverageEpLen : 27.666666666666668
# Train_AverageReturn : 1000.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 1000.0
# Train_MinReturn : 1000.0
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 267879
# TimeSinceStart : 239.536958694458
# Training Loss : 16.26080322265625
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     3004 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 29.214284896850586
# Eval_StdReturn : 12.835100173950195
# Eval_MaxReturn : 52.0
# Eval_MinReturn : 13.0
# Eval_AverageEpLen : 29.214285714285715
# Train_AverageReturn : 31.957447052001953
# Train_StdReturn : 16.009248733520508
# Train_MaxReturn : 88.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 31.95744680851064
# Train_EnvstepsSoFar : 270883
# TimeSinceStart : 241.30490970611572
# Training Loss : -60.75973129272461
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     3079 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 8.416666984558105
# Eval_StdReturn : 2.3614377975463867
# Eval_MaxReturn : 12.0
# Eval_MinReturn : 5.0
# Eval_AverageEpLen : 8.416666666666666
# Train_AverageReturn : 34.59550476074219
# Train_StdReturn : 21.761587142944336
# Train_MaxReturn : 121.0
# Train_MinReturn : 12.0
# Train_AverageEpLen : 34.59550561797753
# Train_EnvstepsSoFar : 273962
# TimeSinceStart : 243.165185213089
# Training Loss : -35.956817626953125
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     3000 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 134.25
# Eval_StdReturn : 87.50250244140625
# Eval_MaxReturn : 263.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 134.25
# Train_AverageReturn : 7.7519378662109375
# Train_StdReturn : 2.2982892990112305
# Train_MaxReturn : 15.0
# Train_MinReturn : 4.0
# Train_AverageEpLen : 7.751937984496124
# Train_EnvstepsSoFar : 276962
# TimeSinceStart : 245.01285910606384
# Training Loss : 63.62452697753906
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     3320 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 89.00
# Eval_StdReturn : 69.79493713378906
# Eval_MaxReturn : 190.0
# Eval_MinReturn : 19.0
# Eval_AverageEpLen : 89.0
# Train_AverageReturn : 174.73684692382812
# Train_StdReturn : 193.13858032226562
# Train_MaxReturn : 853.0
# Train_MinReturn : 14.0
# Train_AverageEpLen : 174.73684210526315
# Train_EnvstepsSoFar : 280282
# TimeSinceStart : 247.95686221122742
# Training Loss : -42.37697982788086
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     3077 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 57.14285659790039
# Eval_StdReturn : 86.62303924560547
# Eval_MaxReturn : 266.0
# Eval_MinReturn : 6.0
# Eval_AverageEpLen : 57.142857142857146
# Train_AverageReturn : 85.47222137451172
# Train_StdReturn : 55.58600997924805
# Train_MaxReturn : 224.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 85.47222222222223
# Train_EnvstepsSoFar : 283359
# TimeSinceStart : 249.9840326309204
# Training Loss : -27.660053253173828
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     3002 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 7.309091091156006
# Eval_StdReturn : 6.260621070861816
# Eval_MaxReturn : 26.0
# Eval_MinReturn : 4.0
# Eval_AverageEpLen : 7.3090909090909095
# Train_AverageReturn : 38.487178802490234
# Train_StdReturn : 55.13636779785156
# Train_MaxReturn : 399.0
# Train_MinReturn : 6.0
# Train_AverageEpLen : 38.48717948717949
# Train_EnvstepsSoFar : 286361
# TimeSinceStart : 251.97320365905762
# Training Loss : -24.269187927246094
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     3040 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 26.933332443237305
# Eval_StdReturn : 12.777409553527832
# Eval_MaxReturn : 64.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 26.933333333333334
# Train_AverageReturn : 10.0
# Train_StdReturn : 14.378117561340332
# Train_MaxReturn : 121.0
# Train_MinReturn : 4.0
# Train_AverageEpLen : 10.0
# Train_EnvstepsSoFar : 289401
# TimeSinceStart : 253.79436421394348
# Training Loss : 13.403636932373047
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     3013 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 33.153846740722656
# Eval_StdReturn : 25.343324661254883
# Eval_MaxReturn : 94.0
# Eval_MinReturn : 3.0
# Eval_AverageEpLen : 33.15384615384615
# Train_AverageReturn : 33.477779388427734
# Train_StdReturn : 16.901826858520508
# Train_MaxReturn : 83.0
# Train_MinReturn : 5.0
# Train_AverageEpLen : 33.477777777777774
# Train_EnvstepsSoFar : 292414
# TimeSinceStart : 255.60548901557922
# Training Loss : 48.774803161621094
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     3002 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 2.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 2.0
# Eval_MinReturn : 2.0
# Eval_AverageEpLen : 2.0
# Train_AverageReturn : 79.0
# Train_StdReturn : 94.23738098144531
# Train_MaxReturn : 459.0
# Train_MinReturn : 5.0
# Train_AverageEpLen : 79.0
# Train_EnvstepsSoFar : 295416
# TimeSinceStart : 257.8202085494995
# Training Loss : -35.409141540527344
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     3000 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 2.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 2.0
# Eval_MinReturn : 2.0
# Eval_AverageEpLen : 2.0
# Train_AverageReturn : 2.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 2.0
# Train_MinReturn : 2.0
# Train_AverageEpLen : 2.0
# Train_EnvstepsSoFar : 298416
# TimeSinceStart : 259.88598704338074
# Training Loss : -40.353633880615234
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     3000 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 2.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 2.0
# Eval_MinReturn : 2.0
# Eval_AverageEpLen : 2.0
# Train_AverageReturn : 2.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 2.0
# Train_MinReturn : 2.0
# Train_AverageEpLen : 2.0
# Train_EnvstepsSoFar : 301416
# TimeSinceStart : 261.9916226863861
# Training Loss : -47.52566909790039
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     3000 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 1.965686321258545
# Eval_StdReturn : 0.18203377723693848
# Eval_MaxReturn : 2.0
# Eval_MinReturn : 1.0
# Eval_AverageEpLen : 1.9656862745098038
# Train_AverageReturn : 2.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 2.0
# Train_MinReturn : 2.0
# Train_AverageEpLen : 2.0
# Train_EnvstepsSoFar : 304416
# TimeSinceStart : 264.1161551475525
# Training Loss : -11.547721862792969
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     3001 / 3000
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 2.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 2.0
# Eval_MinReturn : 2.0
# Eval_AverageEpLen : 2.0
# Train_AverageReturn : 1.9652913808822632
# Train_StdReturn : 0.18304067850112915
# Train_MaxReturn : 2.0
# Train_MinReturn : 1.0
# Train_AverageEpLen : 1.9652914210870989
# Train_EnvstepsSoFar : 307417
# TimeSinceStart : 266.2142131328583
# Training Loss : -81.54143524169922
# Initial_DataCollection_AverageReturn : 8.488700866699219
# Done logging...
